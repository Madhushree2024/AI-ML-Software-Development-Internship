# %%
data = [10,20,30,40,50,60,70,80,90]

# %%
mean = sum(data)/len(data)

# %%
variance = sum((x - mean) ** 2 for x in data) / (len(data) - 1)

# %%
print("Mean:", mean)
# Out:
# Mean: 50.0

# %%
print("Variance:", variance)
# Out:
# Variance: 750.0

# %%
print("Maximum number:", max(data))
# Out:
# Maximum number: 90

# %%
print("Minimum number:", min(data))
# Out:
# Minimum number: 10

# %%
import statistics

print("Mean_value:", statistics.mean(data))
print("Variance_value:", statistics.variance(data))
# Out:
# Mean_value: 50
# Variance_value: 750
